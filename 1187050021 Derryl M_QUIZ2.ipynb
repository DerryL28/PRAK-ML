# %%
import pandas as pd
import seaborn as sns

url ='https://raw.githubusercontent.com/DerryL28/csv/master/FX_IDC_XAUUSD%2C%20240.csv'
df = pd.read_csv(url)
df.head(311)
# Out:
#            time      open      high      low     close         %K         %D
# 0    1640800800  1803.967  1805.670  1801.90  1804.298  26.757208  25.546944
# 1    1640815200  1804.406  1805.510  1800.10  1803.326  31.794397  23.918182
# 2    1640829600  1803.260  1803.580  1797.10  1798.540  36.656436  26.426389
# 3    1640844000  1798.410  1802.250  1795.30  1800.054  43.080489  31.869171
# 4    1640858400  1800.075  1804.720  1797.90  1802.710  42.234889  36.104684
# ..          ...       ...       ...      ...       ...        ...        ...
# 295  1646776800  2049.300  2052.198  2034.80  2041.700  80.756738  83.350896
# 296  1646791200  2041.850  2059.170  2040.00  2047.964  79.983030  82.621656
# 297  1646805600  2047.965  2052.410  2014.40  2017.690  71.727686  79.591434
# 298  1646820000  2017.630  2021.430  1984.84  1989.830  63.247144  75.861837
# 299  1646834400  1989.764  1997.740  1975.73  1995.220  52.713756  69.685671
#
# [300 rows x 7 columns]

# %%
print(df.dtypes)
# Out:
# time       int64
# open     float64
# high     float64
# low      float64
# close    float64
# %K       float64
# %D       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    300 non-null    int64
#  1   open    300 non-null    float64
#  2   high    300 non-null    float64
#  3   low     300 non-null    float64
#  4   close   300 non-null    float64
#  5   %K      300 non-null    float64
#  6   %D      300 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 16.5 KB

# %%
df.describe()
# Out:
#                time         open         high          low        close  \
# count  3.000000e+02   300.000000   300.000000   300.000000   300.000000
# mean   1.643829e+09  1852.317697  1857.753170  1846.866460  1853.013467
# std    1.751896e+06    57.562447    60.496935    55.784897    58.081115
# min    1.640801e+09  1783.900000  1790.280000  1779.300000  1784.010000
# 25%    1.642396e+09  1810.212500  1815.052500  1805.375000  1810.420000
# 50%    1.643818e+09  1827.417000  1832.935000  1824.300000  1827.675000
# 75%    1.645412e+09  1895.762500  1899.172500  1888.540000  1895.936000
# max    1.646834e+09  2049.300000  2070.420000  2040.000000  2050.168000
#
#                %K          %D
# count  300.000000  300.000000
# mean    62.494874   62.225516
# std     24.770770   23.630055
# min      6.096135    7.890524
# 25%     43.829490   45.626368
# 50%     68.138928   69.340442
# 75%     83.642484   82.462919
# max     95.396966   93.661393

# %%
df.count()
# Out:
# time     300
# open     300
# high     300
# low      300
# close    300
# %K       300
# %D       300
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                time         open         high          low        close  \
# count  3.000000e+02   300.000000   300.000000   300.000000   300.000000
# mean   1.643829e+09  1852.317697  1857.753170  1846.866460  1853.013467
# std    1.751896e+06    57.562447    60.496935    55.784897    58.081115
# min    1.640801e+09  1783.900000  1790.280000  1779.300000  1784.010000
# 25%    1.642396e+09  1810.212500  1815.052500  1805.375000  1810.420000
# 50%    1.643818e+09  1827.417000  1832.935000  1824.300000  1827.675000
# 75%    1.645412e+09  1895.762500  1899.172500  1888.540000  1895.936000
# max    1.646834e+09  2049.300000  2070.420000  2040.000000  2050.168000
#
#                %K          %D
# count  300.000000  300.000000
# mean    62.494874   62.225516
# std     24.770770   23.630055
# min      6.096135    7.890524
# 25%     43.829490   45.626368
# 50%     68.138928   69.340442
# 75%     83.642484   82.462919
# max     95.396966   93.661393

# %%
df.fillna(311)
# Out:
#            time      open      high      low     close         %K         %D
# 0    1640800800  1803.967  1805.670  1801.90  1804.298  26.757208  25.546944
# 1    1640815200  1804.406  1805.510  1800.10  1803.326  31.794397  23.918182
# 2    1640829600  1803.260  1803.580  1797.10  1798.540  36.656436  26.426389
# 3    1640844000  1798.410  1802.250  1795.30  1800.054  43.080489  31.869171
# 4    1640858400  1800.075  1804.720  1797.90  1802.710  42.234889  36.104684
# ..          ...       ...       ...      ...       ...        ...        ...
# 295  1646776800  2049.300  2052.198  2034.80  2041.700  80.756738  83.350896
# 296  1646791200  2041.850  2059.170  2040.00  2047.964  79.983030  82.621656
# 297  1646805600  2047.965  2052.410  2014.40  2017.690  71.727686  79.591434
# 298  1646820000  2017.630  2021.430  1984.84  1989.830  63.247144  75.861837
# 299  1646834400  1989.764  1997.740  1975.73  1995.220  52.713756  69.685671
#
# [300 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    300 non-null    int64
#  1   open    300 non-null    float64
#  2   high    300 non-null    float64
#  3   low     300 non-null    float64
#  4   close   300 non-null    float64
#  5   %K      300 non-null    float64
#  6   %D      300 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 16.5 KB

# %%
df['open'] = df['open'].fillna(0)
df['high'] = df['high'].fillna(0)
df['low'] = df['low'].fillna(0)
df['close'] = df['close'].fillna(0)
df['%K'] = df['%K'].fillna(0)
df['%D'] = df['%D'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    300 non-null    int64
#  1   open    300 non-null    float64
#  2   high    300 non-null    float64
#  3   low     300 non-null    float64
#  4   close   300 non-null    float64
#  5   %K      300 non-null    float64
#  6   %D      300 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 16.5 KB

# %%
df.describe(include='all')
# Out:
#                time         open         high          low        close  \
# count  3.000000e+02   300.000000   300.000000   300.000000   300.000000
# mean   1.643829e+09  1852.317697  1857.753170  1846.866460  1853.013467
# std    1.751896e+06    57.562447    60.496935    55.784897    58.081115
# min    1.640801e+09  1783.900000  1790.280000  1779.300000  1784.010000
# 25%    1.642396e+09  1810.212500  1815.052500  1805.375000  1810.420000
# 50%    1.643818e+09  1827.417000  1832.935000  1824.300000  1827.675000
# 75%    1.645412e+09  1895.762500  1899.172500  1888.540000  1895.936000
# max    1.646834e+09  2049.300000  2070.420000  2040.000000  2050.168000
#
#                %K          %D
# count  300.000000  300.000000
# mean    62.494874   62.225516
# std     24.770770   23.630055
# min      6.096135    7.890524
# 25%     43.829490   45.626368
# 50%     68.138928   69.340442
# 75%     83.642484   82.462919
# max     95.396966   93.661393

# %%
df.corr()
# Out:
#            time      open      high       low     close        %K        %D
# time   1.000000  0.814324  0.813170  0.815747  0.816252  0.179926  0.206517
# open   0.814324  1.000000  0.995400  0.994442  0.991493  0.270333  0.285905
# high   0.813170  0.995400  1.000000  0.993726  0.995643  0.263975  0.272315
# low    0.815747  0.994442  0.993726  1.000000  0.996861  0.277430  0.283277
# close  0.816252  0.991493  0.995643  0.996861  1.000000  0.275179  0.274240
# %K     0.179926  0.270333  0.263975  0.277430  0.275179  1.000000  0.896358
# %D     0.206517  0.285905  0.272315  0.283277  0.274240  0.896358  1.000000
