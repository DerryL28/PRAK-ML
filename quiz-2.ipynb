# %%
import pandas as pd
import seaborn as sns

url ='https://raw.githubusercontent.com/DerryL28/csv/master/FX_IDC_XAUUSD%2C%20240.csv'
df = pd.read_csv(url)
df.head(311)

# %%
print(df.dtypes)

# %%
df.info()

# %%
df.describe()

# %%
df.count()

# %%
df.describe(include='all')

# %%
df.fillna(311)

# %%
df.info()

# %%
df['open'] = df['open'].fillna(0)
df['high'] = df['high'].fillna(0)
df['low'] = df['low'].fillna(0)
df['close'] = df['close'].fillna(0)
df['%K'] = df['%K'].fillna(0)
df['%D'] = df['%D'].fillna(0)

# %%
df.info()

# %%
df.describe(include='all')

# %%
df.corr()
